# %%
# %matplotlib inline
import matplotlib.pyplot as plt   #载入matplotlib库
import numpy as np    #载入numpy
import tensorflow.compat.v1 as tf
from IPython.display import Image

tf.disable_v2_behavior()

#清除default_graph和不断增加的节点
tf.reset_default_graph()

#路径
logdir = "D:/log"



#import tensorflow as tf     #载入tensorflow,tensorflow2.0不支持placeholder
np.random.seed(5)   #设置伪随机种子，种子相同每次生成的随机序列也相同

# 区间变换,[0,100]化为[-1,1]
def Convert(data,Min,Max,size):
    # data：需要变换的数据或矩阵
    # Min：最小值        
    # Max：最大值
    #size:样本个数
    data = np.array(data)
    Size = size
    w = -2/(Min - Max)
    b = (Min + Max)/(Min - Max)
    for i in range(Size):
            data[i] = data[i]*w + b
    return data



#生成 x_data，值为 [0, 100]之间500个等差数列数据集合作为样本特征
x_data = np.linspace(0,100,500)
x_data = Convert(x_data,0,100,500)


#根据目标线性方程 y=3.1234*x+2.98，生成相应的标签集合 y_data，噪声最大振幅0.4
y_data = 3.1234 * x_data + 2.98 + np.random.randn(*x_data.shape) *0.4

#画出随机生成数据的散点图
plt.scatter(x_data,y_data)

#画出通过学习得到的目标线性函数 y=3.1234*x+2.98
plt.plot(x_data,3.1234 * x_data + 2.98,color = "red", linewidth = 2)

#定义数据的占位符,x为特征值，y为标签值
x = tf.placeholder("float", name = "x")
y = tf.placeholder("float",name ="y")

#定义模型函数
def model(x,w,b):
    return tf.multiply(x,w) + b

#定义模型结构：

#构建线性函数的斜率，变量w
w = tf.Variable(1.0,name="w0")
#构建线性函数的截距，变量b
b = tf.Variable(0.0,name="b0")

#pred是预测值，前向计算
pred = model(x,w,b)

#设置训练参数10轮，每训练20个样本显示损失值
train_epochs = 10
step = 0
display_step = 20   #显示的步数
loss_list = []   #初始化空列表，用于保存损失值

learning_rate = 0.05   #学习率

#采用均方差作为损失函数
loss_function = tf.reduce_mean(tf.square(y-pred))

#梯度下降优化器
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss_function)

#声明回话
sess = tf.Session()

#变量初始化
init = tf.global_variables_initializer()
sess.run(init)


#开始进行迭代训练
for epoch in range(train_epochs):
    for xs,ys in zip(x_data,y_data):
        _,loss = sess.run([optimizer,loss_function],feed_dict = {x:xs , y:ys})
        loss_list.append(loss)     #将损失函数值增加到列表末端
        step += 1     #步长加1
        
        
        
        if step % display_step == 0:
            print("Train Epoch:{0:d}  Step:{1:d}  loss:{2:.9f}".format(epoch+1,step,loss))
            
    b0temp = b.eval(session = sess)
    w0temp = w.eval(session = sess)
    plt.plot(x_data,w0temp*x_data +b0temp)    #画预测图
    
print("w:",sess.run(w))
print("b:",sess.run(b))


#通过训练出的模型预测 x=5.79 时 y 的值
x_test = 5.79

predict = sess.run(pred,feed_dict={x:x_test})
print("预测值：{:.9f}".format(predict))

target = 3.1234 * x_test + 2.98 
print("目标值：{:.9f}".format(target))


#生成一个写日志的writer,并将当前的tensorflow计算图写入日志
writer = tf.summary.FileWriter(logdir,tf.get_default_graph())
writer.close()
Image(filename = 'D:\\Photo\\结果图.png', width=320, height=240)   #插入图片
# Out:
# Train Epoch:1  Step:20  loss:0.131197810
# Train Epoch:1  Step:40  loss:0.366075784
# Train Epoch:1  Step:60  loss:0.004311353
# Train Epoch:1  Step:80  loss:0.002796804
# Train Epoch:1  Step:100  loss:0.090841033
# Train Epoch:1  Step:120  loss:0.016047705
# Train Epoch:1  Step:140  loss:0.350193202
# Train Epoch:1  Step:160  loss:0.004568473
# Train Epoch:1  Step:180  loss:0.041128483
# Train Epoch:1  Step:200  loss:0.114690274
# Train Epoch:1  Step:220  loss:0.061894696
# Train Epoch:1  Step:240  loss:0.078019530
# Train Epoch:1  Step:260  loss:0.006248083
# Train Epoch:1  Step:280  loss:0.053734042
# Train Epoch:1  Step:300  loss:0.000083192
# Train Epoch:1  Step:320  loss:0.049296971
# Train Epoch:1  Step:340  loss:0.039168112
# Train Epoch:1  Step:360  loss:0.026956573
# Train Epoch:1  Step:380  loss:0.123416886
# Train Epoch:1  Step:400  loss:0.195363507
# Train Epoch:1  Step:420  loss:0.151460096
# Train Epoch:1  Step:440  loss:0.004886148
# Train Epoch:1  Step:460  loss:0.003584903
# Train Epoch:1  Step:480  loss:0.003805403
# Train Epoch:1  Step:500  loss:0.166240722
# Train Epoch:2  Step:520  loss:0.045915041
# Train Epoch:2  Step:540  loss:0.293999046
# Train Epoch:2  Step:560  loss:0.017996853
# Train Epoch:2  Step:580  loss:0.000557708
# Train Epoch:2  Step:600  loss:0.046766669
# Train Epoch:2  Step:620  loss:0.001053588
# Train Epoch:2  Step:640  loss:0.238414273
# Train Epoch:2  Step:660  loss:0.002028356
# Train Epoch:2  Step:680  loss:0.104970515
# Train Epoch:2  Step:700  loss:0.044091504
# Train Epoch:2  Step:720  loss:0.146961167
# Train Epoch:2  Step:740  loss:0.174462184
# Train Epoch:2  Step:760  loss:0.003679564
# Train Epoch:2  Step:780  loss:0.137054682
# Train Epoch:2  Step:800  loss:0.020633010
# Train Epoch:2  Step:820  loss:0.122767940
# Train Epoch:2  Step:840  loss:0.101310648
# Train Epoch:2  Step:860  loss:0.075835004
# Train Epoch:2  Step:880  loss:0.204929218
# Train Epoch:2  Step:900  loss:0.122871719
# Train Epoch:2  Step:920  loss:0.221876666
# Train Epoch:2  Step:940  loss:0.020372465
# Train Epoch:2  Step:960  loss:0.000021837
# Train Epoch:2  Step:980  loss:0.014104983
# Train Epoch:2  Step:1000  loss:0.127666563
# Train Epoch:3  Step:1020  loss:0.085657395
# Train Epoch:3  Step:1040  loss:0.294557780
# Train Epoch:3  Step:1060  loss:0.018281674
# Train Epoch:3  Step:1080  loss:0.000617008
# Train Epoch:3  Step:1100  loss:0.046178892
# Train Epoch:3  Step:1120  loss:0.000957936
# Train Epoch:3  Step:1140  loss:0.236798629
# Train Epoch:3  Step:1160  loss:0.002194037
# Train Epoch:3  Step:1180  loss:0.106231838
# Train Epoch:3  Step:1200  loss:0.043230459
# Train Epoch:3  Step:1220  loss:0.148617744
# Train Epoch:3  Step:1240  loss:0.176317766
# Train Epoch:3  Step:1260  loss:0.003955969
# Train Epoch:3  Step:1280  loss:0.138700441
# Train Epoch:3  Step:1300  loss:0.021256283
# Train Epoch:3  Step:1320  loss:0.124212526
# Train Epoch:3  Step:1340  loss:0.102541305
# Train Epoch:3  Step:1360  loss:0.076818816
# Train Epoch:3  Step:1380  loss:0.206401855
# Train Epoch:3  Step:1400  loss:0.121846922
# Train Epoch:3  Step:1420  loss:0.223113284
# Train Epoch:3  Step:1440  loss:0.020706775
# Train Epoch:3  Step:1460  loss:0.000032562
# Train Epoch:3  Step:1480  loss:0.014322943
# Train Epoch:3  Step:1500  loss:0.127090320
# Train Epoch:4  Step:1520  loss:0.086393736
# Train Epoch:4  Step:1540  loss:0.294566572
# Train Epoch:4  Step:1560  loss:0.018286187
# Train Epoch:4  Step:1580  loss:0.000617979
# Train Epoch:4  Step:1600  loss:0.046169721
# Train Epoch:4  Step:1620  loss:0.000956409
# Train Epoch:4  Step:1640  loss:0.236772984
# Train Epoch:4  Step:1660  loss:0.002196752
# Train Epoch:4  Step:1680  loss:0.106251888
# Train Epoch:4  Step:1700  loss:0.043216780
# Train Epoch:4  Step:1720  loss:0.148644775
# Train Epoch:4  Step:1740  loss:0.176347598
# Train Epoch:4  Step:1760  loss:0.003960468
# Train Epoch:4  Step:1780  loss:0.138726726
# Train Epoch:4  Step:1800  loss:0.021266434
# Train Epoch:4  Step:1820  loss:0.124235719
# Train Epoch:4  Step:1840  loss:0.102561459
# Train Epoch:4  Step:1860  loss:0.076834679
# Train Epoch:4  Step:1880  loss:0.206425250
# Train Epoch:4  Step:1900  loss:0.121830605
# Train Epoch:4  Step:1920  loss:0.223133102
# Train Epoch:4  Step:1940  loss:0.020712128
# Train Epoch:4  Step:1960  loss:0.000032753
# Train Epoch:4  Step:1980  loss:0.014326253
# Train Epoch:4  Step:2000  loss:0.127081141
# Train Epoch:5  Step:2020  loss:0.086405374
# Train Epoch:5  Step:2040  loss:0.294566303
# Train Epoch:5  Step:2060  loss:0.018286316
# Train Epoch:5  Step:2080  loss:0.000617991
# Train Epoch:5  Step:2100  loss:0.046169516
# Train Epoch:5  Step:2120  loss:0.000956387
# Train Epoch:5  Step:2140  loss:0.236772642
# Train Epoch:5  Step:2160  loss:0.002196763
# Train Epoch:5  Step:2180  loss:0.106252357
# Train Epoch:5  Step:2200  loss:0.043216381
# Train Epoch:5  Step:2220  loss:0.148645148
# Train Epoch:5  Step:2240  loss:0.176348403
# Train Epoch:5  Step:2260  loss:0.003960559
# Train Epoch:5  Step:2280  loss:0.138727263
# Train Epoch:5  Step:2300  loss:0.021266503
# Train Epoch:5  Step:2320  loss:0.124235883
# Train Epoch:5  Step:2340  loss:0.102561459
# Train Epoch:5  Step:2360  loss:0.076834679
# Train Epoch:5  Step:2380  loss:0.206425682
# Train Epoch:5  Step:2400  loss:0.121830605
# Train Epoch:5  Step:2420  loss:0.223133102
# Train Epoch:5  Step:2440  loss:0.020712128
# Train Epoch:5  Step:2460  loss:0.000032753
# Train Epoch:5  Step:2480  loss:0.014326481
# Train Epoch:5  Step:2500  loss:0.127081141
# Train Epoch:6  Step:2520  loss:0.086405508
# Train Epoch:6  Step:2540  loss:0.294566572
# Train Epoch:6  Step:2560  loss:0.018286381
# Train Epoch:6  Step:2580  loss:0.000618003
# Train Epoch:6  Step:2600  loss:0.046169464
# Train Epoch:6  Step:2620  loss:0.000956387
# Train Epoch:6  Step:2640  loss:0.236772522
# Train Epoch:6  Step:2660  loss:0.002196774
# Train Epoch:6  Step:2680  loss:0.106252044
# Train Epoch:6  Step:2700  loss:0.043216381
# Train Epoch:6  Step:2720  loss:0.148645148
# Train Epoch:6  Step:2740  loss:0.176348403
# Train Epoch:6  Step:2760  loss:0.003960559
# Train Epoch:6  Step:2780  loss:0.138727441
# Train Epoch:6  Step:2800  loss:0.021266503
# Train Epoch:6  Step:2820  loss:0.124236055
# Train Epoch:6  Step:2840  loss:0.102561459
# Train Epoch:6  Step:2860  loss:0.076834679
# Train Epoch:6  Step:2880  loss:0.206425682
# Train Epoch:6  Step:2900  loss:0.121830605
# Train Epoch:6  Step:2920  loss:0.223133102
# Train Epoch:6  Step:2940  loss:0.020712264
# Train Epoch:6  Step:2960  loss:0.000032753
# Train Epoch:6  Step:2980  loss:0.014326481
# Train Epoch:6  Step:3000  loss:0.127081141
# Train Epoch:7  Step:3020  loss:0.086405508
# Train Epoch:7  Step:3040  loss:0.294566303
# Train Epoch:7  Step:3060  loss:0.018286316
# Train Epoch:7  Step:3080  loss:0.000617991
# Train Epoch:7  Step:3100  loss:0.046169516
# Train Epoch:7  Step:3120  loss:0.000956387
# Train Epoch:7  Step:3140  loss:0.236772642
# Train Epoch:7  Step:3160  loss:0.002196763
# Train Epoch:7  Step:3180  loss:0.106252357
# Train Epoch:7  Step:3200  loss:0.043216381
# Train Epoch:7  Step:3220  loss:0.148645148
# Train Epoch:7  Step:3240  loss:0.176348403
# Train Epoch:7  Step:3260  loss:0.003960559
# Train Epoch:7  Step:3280  loss:0.138727263
# Train Epoch:7  Step:3300  loss:0.021266503
# Train Epoch:7  Step:3320  loss:0.124235883
# Train Epoch:7  Step:3340  loss:0.102561459
# Train Epoch:7  Step:3360  loss:0.076834679
# Train Epoch:7  Step:3380  loss:0.206425682
# Train Epoch:7  Step:3400  loss:0.121830605
# Train Epoch:7  Step:3420  loss:0.223133102
# Train Epoch:7  Step:3440  loss:0.020712128
# Train Epoch:7  Step:3460  loss:0.000032753
# Train Epoch:7  Step:3480  loss:0.014326481
# Train Epoch:7  Step:3500  loss:0.127081141
# Train Epoch:8  Step:3520  loss:0.086405508
# Train Epoch:8  Step:3540  loss:0.294566572
# Train Epoch:8  Step:3560  loss:0.018286381
# Train Epoch:8  Step:3580  loss:0.000618003
# Train Epoch:8  Step:3600  loss:0.046169464
# Train Epoch:8  Step:3620  loss:0.000956387
# Train Epoch:8  Step:3640  loss:0.236772522
# Train Epoch:8  Step:3660  loss:0.002196774
# Train Epoch:8  Step:3680  loss:0.106252044
# Train Epoch:8  Step:3700  loss:0.043216381
# Train Epoch:8  Step:3720  loss:0.148645148
# Train Epoch:8  Step:3740  loss:0.176348403
# Train Epoch:8  Step:3760  loss:0.003960559
# Train Epoch:8  Step:3780  loss:0.138727441
# Train Epoch:8  Step:3800  loss:0.021266503
# Train Epoch:8  Step:3820  loss:0.124236055
# Train Epoch:8  Step:3840  loss:0.102561459
# Train Epoch:8  Step:3860  loss:0.076834679
# Train Epoch:8  Step:3880  loss:0.206425682
# Train Epoch:8  Step:3900  loss:0.121830605
# Train Epoch:8  Step:3920  loss:0.223133102
# Train Epoch:8  Step:3940  loss:0.020712264
# Train Epoch:8  Step:3960  loss:0.000032753
# Train Epoch:8  Step:3980  loss:0.014326481
# Train Epoch:8  Step:4000  loss:0.127081141
# Train Epoch:9  Step:4020  loss:0.086405508
# Train Epoch:9  Step:4040  loss:0.294566303
# Train Epoch:9  Step:4060  loss:0.018286316
# Train Epoch:9  Step:4080  loss:0.000617991
# Train Epoch:9  Step:4100  loss:0.046169516
# Train Epoch:9  Step:4120  loss:0.000956387
# Train Epoch:9  Step:4140  loss:0.236772642
# Train Epoch:9  Step:4160  loss:0.002196763
# Train Epoch:9  Step:4180  loss:0.106252357
# Train Epoch:9  Step:4200  loss:0.043216381
# Train Epoch:9  Step:4220  loss:0.148645148
# Train Epoch:9  Step:4240  loss:0.176348403
# Train Epoch:9  Step:4260  loss:0.003960559
# Train Epoch:9  Step:4280  loss:0.138727263
# Train Epoch:9  Step:4300  loss:0.021266503
# Train Epoch:9  Step:4320  loss:0.124235883
# Train Epoch:9  Step:4340  loss:0.102561459
# Train Epoch:9  Step:4360  loss:0.076834679
# Train Epoch:9  Step:4380  loss:0.206425682
# Train Epoch:9  Step:4400  loss:0.121830605
# Train Epoch:9  Step:4420  loss:0.223133102
# Train Epoch:9  Step:4440  loss:0.020712128
# Train Epoch:9  Step:4460  loss:0.000032753
# Train Epoch:9  Step:4480  loss:0.014326481
# Train Epoch:9  Step:4500  loss:0.127081141
# Train Epoch:10  Step:4520  loss:0.086405508
# Train Epoch:10  Step:4540  loss:0.294566572
# Train Epoch:10  Step:4560  loss:0.018286381
# Train Epoch:10  Step:4580  loss:0.000618003
# Train Epoch:10  Step:4600  loss:0.046169464
# Train Epoch:10  Step:4620  loss:0.000956387
# Train Epoch:10  Step:4640  loss:0.236772522
# Train Epoch:10  Step:4660  loss:0.002196774
# Train Epoch:10  Step:4680  loss:0.106252044
# Train Epoch:10  Step:4700  loss:0.043216381
# Train Epoch:10  Step:4720  loss:0.148645148
# Train Epoch:10  Step:4740  loss:0.176348403
# Train Epoch:10  Step:4760  loss:0.003960559
# Train Epoch:10  Step:4780  loss:0.138727441
# Train Epoch:10  Step:4800  loss:0.021266503
# Train Epoch:10  Step:4820  loss:0.124236055
# Train Epoch:10  Step:4840  loss:0.102561459
# Train Epoch:10  Step:4860  loss:0.076834679
# Train Epoch:10  Step:4880  loss:0.206425682
# Train Epoch:10  Step:4900  loss:0.121830605
# Train Epoch:10  Step:4920  loss:0.223133102
# Train Epoch:10  Step:4940  loss:0.020712264
# Train Epoch:10  Step:4960  loss:0.000032753
# Train Epoch:10  Step:4980  loss:0.014326481
# Train Epoch:10  Step:5000  loss:0.127081141
# w: 3.1424234
# b: 2.985063
# 预测值：21.179695129
# 目标值：21.064486000
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6d7c2d810ee8> in <module>
#     121 writer = tf.summary.FileWriter(logdir,tf.get_default_graph())
#     122 writer.close()
# --> 123 Image(filename = 'D:\\Photo\\结果图.png', width=320, height=240)   #插入图片
#     124
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1222         self.retina = retina
#    1223         self.unconfined = unconfined
# -> 1224         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1225                 metadata=metadata)
#    1226
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     628             self.metadata = {}
#     629
# --> 630         self.reload()
#     631         self._check_data()
#     632
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in reload(self)
#    1254         """Reload the raw data from file or URL."""
#    1255         if self.embed:
# -> 1256             super(Image,self).reload()
#    1257             if self.retina:
#    1258                 self._retina_shape()
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in reload(self)
#     653         """Reload the raw data from file or URL."""
#     654         if self.filename is not None:
# --> 655             with open(self.filename, self._read_flags) as f:
#     656                 self.data = f.read()
#     657         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Photo\\结果图.png'
